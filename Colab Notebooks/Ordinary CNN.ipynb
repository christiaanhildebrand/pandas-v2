# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Concatenate, Dropout, BatchNormalization
from tensorflow.keras.applications import MobileNetV2, ResNet50
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import os
# Out:
# Mounted at /content/drive

# %%
images_path = '/content/drive/MyDrive/Contrastive Learning/contrastive_learning_images'
labels_path = '/content/drive/MyDrive/Contrastive Learning/contrastive_learning_labels.csv'

# Load the labels
labels_df = pd.read_csv(labels_path)

# Split into training and validation sets
train_df, val_df = train_test_split(labels_df, test_size=0.2, random_state=42)

# Standardize the scalar features
scaler = StandardScaler()
train_df[['pothole_area_mm2', 'mm_to_pixel_ratio']] = scaler.fit_transform(train_df[['pothole_area_mm2', 'mm_to_pixel_ratio']])
val_df[['pothole_area_mm2', 'mm_to_pixel_ratio']] = scaler.transform(val_df[['pothole_area_mm2', 'mm_to_pixel_ratio']])

# Function to preprocess and load the image
def preprocess_image(image_path):
    img = load_img(image_path, target_size=(224, 224))
    img_array = img_to_array(img)
    img_array = img_array / 255.0  # Normalize to [0, 1]
    return img_array

# Image data generator with augmentation (excluding scale transformations)
datagen = ImageDataGenerator(
    rotation_range=10,  # Less aggressive rotation
    width_shift_range=0.02,  # Smaller shifts
    height_shift_range=0.02,  # Smaller shifts
    shear_range=0.05,  # Reduced shear
    horizontal_flip=True,  # Flipping is okay
    fill_mode='nearest'
)

# Custom R² metric
def r2_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    SS_res = tf.reduce_sum(tf.square(y_true - y_pred))
    SS_tot = tf.reduce_sum(tf.square(y_true - tf.reduce_mean(y_true)))
    return 1 - SS_res / (SS_tot + tf.keras.backend.epsilon())

def logcosh_loss(y_true, y_pred):
    return tf.keras.backend.mean(tf.math.log(tf.math.cosh(y_pred - y_true)), axis=-1)

# Build a simplified model using MobileNetV2
def build_simple_model():
    base_model = tf.keras.applications.EfficientNetB0(include_top=False, input_shape=(224, 224, 3))

    # Unfreeze some layers for fine-tuning
    for layer in base_model.layers[-10:]:
        layer.trainable = True

    image_input = Input(shape=(224, 224, 3), name='image_input')
    scalar_input = Input(shape=(2,), name='scalar_input')

    # Process the image through the CNN
    x = base_model(image_input)
    x = GlobalAveragePooling2D()(x)

    # Concatenate the scalar input
    x = Concatenate()([x, scalar_input])

    # Add even more simplified fully connected layers
    x = Dense(64, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)
    x = Dense(32, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)
    output = Dense(1, activation='relu')(x)  # Output layer for regression

    model = Model(inputs=[image_input, scalar_input], outputs=output)

    # Compile the model with a lower learning rate
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
              loss=logcosh_loss,
              metrics=[r2_metric])


    return model

# Custom data generator
def data_generator(df, images_path, batch_size, augment=False):
    num_samples = len(df)
    while True:  # Loop forever so the generator never terminates
        df = df.sample(frac=1).reset_index(drop=True)  # Shuffle the dataframe each epoch
        for offset in range(0, num_samples, batch_size):
            batch_df = df[offset:offset+batch_size]

            X_images = []
            X_scalars = []
            y = []

            for _, row in batch_df.iterrows():
                image_path = os.path.join(images_path, f"{row['pothole_id']}.jpg")
                image = preprocess_image(image_path)
                scalar_features = np.array([row['pothole_area_mm2'], row['mm_to_pixel_ratio']])

                X_images.append(image)
                X_scalars.append(scalar_features)
                y.append(row['bags_used'])

            X_images = np.array(X_images)
            X_scalars = np.array(X_scalars)
            y = np.array(y)

            if augment:
                X_images, y = next(datagen.flow(X_images, y, batch_size=batch_size, shuffle=False))

            yield ({'image_input': X_images, 'scalar_input': X_scalars}, y)

# Instantiate the simplified model
model = build_simple_model()

# Prepare data generators for training and validation
batch_size = 16
train_gen = data_generator(train_df, images_path, batch_size=batch_size, augment=True)
val_gen = data_generator(val_df, images_path, batch_size=batch_size, augment=False)

# Train the model
history = model.fit(
    train_gen,
    steps_per_epoch=len(train_df) // batch_size,
    validation_data=val_gen,
    validation_steps=len(val_df) // batch_size,
    epochs=500,  # Adjust as needed
    verbose=1,
    callbacks=[
        EarlyStopping(monitor='val_r2_metric', patience=100, restore_best_weights=True, mode='max', verbose=1),
        ModelCheckpoint('/content/drive/MyDrive/Contrastive Learning/bags_used_predictor_simple_huber.keras', monitor='val_loss', save_best_only=True, verbose=1)
    ]
)

# Save the final model
model.save('/content/drive/MyDrive/Contrastive Learning/bags_used_predictor_simple_final_huber.keras')
# Out:
# Epoch 1/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.6740 - r2_metric: -107.4085
# Epoch 1: val_loss improved from inf to 0.40503, saving model to /content/drive/MyDrive/Contrastive Learning/bags_used_predictor_simple_huber.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 722s 15s/step - loss: 0.6744 - r2_metric: -107.2201 - val_loss: 0.4050 - val_r2_metric: -50.4564
# Epoch 2/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - loss: 0.5971 - r2_metric: -105.6718
# Epoch 2: val_loss improved from 0.40503 to 0.39307, saving model to /content/drive/MyDrive/Contrastive Learning/bags_used_predictor_simple_huber.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 71s 545ms/step - loss: 0.5975 - r2_metric: -105.6053 - val_loss: 0.3931 - val_r2_metric: -41.1537
# Epoch 3/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - loss: 0.5797 - r2_metric: -71.0753
# Epoch 3: val_loss did not improve from 0.39307
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 362ms/step - loss: 0.5795 - r2_metric: -71.1705 - val_loss: 0.4394 - val_r2_metric: -61.8804
# Epoch 4/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - loss: 0.6562 - r2_metric: -103.7496
# Epoch 4: val_loss improved from 0.39307 to 0.30478, saving model to /content/drive/MyDrive/Contrastive Learning/bags_used_predictor_simple_huber.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 19s 456ms/step - loss: 0.6560 - r2_metric: -103.5483 - val_loss: 0.3048 - val_r2_metric: -42.8532
# Epoch 5/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - loss: 0.5800 - r2_metric: -111.0951
# Epoch 5: val_loss did not improve from 0.30478
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 346ms/step - loss: 0.5798 - r2_metric: -110.5371 - val_loss: 0.4658 - val_r2_metric: -33.4491
# Epoch 6/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - loss: 0.7276 - r2_metric: -99.3141
# Epoch 6: val_loss did not improve from 0.30478
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 16s 362ms/step - loss: 0.7259 - r2_metric: -99.6052 - val_loss: 0.4051 - val_r2_metric: -47.4721
# Epoch 7/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - loss: 0.6295 - r2_metric: -75.1370
# Epoch 7: val_loss did not improve from 0.30478
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 16s 366ms/step - loss: 0.6284 - r2_metric: -75.4446 - val_loss: 0.4588 - val_r2_metric: -34.6431
# Epoch 8/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - loss: 0.7561 - r2_metric: -59.2699
# Epoch 8: val_loss did not improve from 0.30478
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 16s 367ms/step - loss: 0.7539 - r2_metric: -59.4697 - val_loss: 0.4075 - val_r2_metric: -643.1013
# Epoch 9/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 0.5618 - r2_metric: -126.9616
# Epoch 9: val_loss did not improve from 0.30478
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 360ms/step - loss: 0.5625 - r2_metric: -126.2877 - val_loss: 0.6231 - val_r2_metric: -122.7973
# Epoch 10/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - loss: 0.6076 - r2_metric: -76.7884
# Epoch 10: val_loss did not improve from 0.30478
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 16s 364ms/step - loss: 0.6082 - r2_metric: -77.1083 - val_loss: 0.6179 - val_r2_metric: -114.1876
# Epoch 11/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - loss: 0.5738 - r2_metric: -77.5009
# Epoch 11: val_loss did not improve from 0.30478
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 16s 371ms/step - loss: 0.5746 - r2_metric: -77.4962 - val_loss: 0.4053 - val_r2_metric: -48.4649
# Epoch 12/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - loss:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 16s 372ms/step - loss: 0.5921 - r2_metric: -74.1352 - val_loss: 0.3808 - val_r2_metric: -26.6719
# Epoch 27/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 0.5672 - r2_metric: -77.3163
# Epoch 27: val_loss did not improve from 0.26751
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 360ms/step - loss: 0.5667 - r2_metric: -77.6941 - val_loss: 0.3220 - val_r2_metric: -58.3675
# Epoch 28/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 0.5107 - r2_metric: -71.2694
# Epoch 28: val_loss improved from 0.26751 to 0.25123, saving model to /content/drive/MyDrive/Contrastive Learning/bags_used_predictor_simple_huber.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 18s 429ms/step - loss: 0.5121 - r2_metric: -71.3738 - val_loss: 0.2512 - val_r2_metric: -48472140.0000
# Epoch 29/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - loss: 0.4615 - r2_metric: -89.8135
# Epoch 29: val_loss did not improve from 0.25123
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 14s 323ms/step - loss: 0.4623 - r2_metric: -89.5056 - val_loss: 0.4281 - val_r2_metric: -34.4723
# Epoch 30/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - loss: 0.5657 - r2_metric: -75.2646
# Epoch 30: val_loss did not improve from 0.25123
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.5658 - r2_metric: -75.1393 - val_loss: 0.2701 - val_r2_metric: -78.1018
# Epoch 31/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - loss: 0.4925 - r2_metric: -79.2842
# Epoch 31: val_loss did not improve from 0.25123
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 356ms/step - loss: 0.4939 - r2_metric: -79.5432 - val_loss: 0.3803 - val_r2_metric: -35.7214
# Epoch 32/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - loss: 0.5025 - r2_metric: -77.7873
# Epoch 32: val_loss did not improve from 0.25123
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 355ms/step - loss: 0.5026 - r2_metric: -77.7346 - val_loss: 0.3217 - val_r2_metric: -47.0372
# Epoch 33/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - loss: 0.5628 - r2_metric: -79.5725
# Epoch 33: val_loss did not improve from 0.25123
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.5623 - r2_metric: -79.7297 - val_loss: 0.3332 - val_r2_metric: -53.6437
# Epoch 34/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - loss: 0.4381 - r2_metric: -69.9044
# Epoch 34: val_loss did not improve from 0.25123
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 16s 366ms/step - loss: 0.4394 - r2_metric: -69.9444 - val_loss: 0.3487 - val_r2_metric: -36.9670
# Epoch 35/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - loss: 0.5576 - r2_metric: -75.5924
# Epoch 35: val_loss did not improve from 0.25123
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 16s 365ms/step - loss: 0.5570 - r2_metric: -75.5661 - val_loss: 0.3432 - val_r2_metric: -46.1695
# Epoch 36/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - loss: 0.4807 - r2_metric: -84.0335
# Epoch 36: val_loss did not improve from 0.25123
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 16s 365ms/step - loss: 0.4816 - r2_metric: -84.0601 - val_loss: 0.3020 - val_r2_metric: -47.7835
# Epoch 37/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - loss: 0.5497 - r2_metric: -84.7209
# Epoch 37: val_loss did not improve from 0.25123
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 16s 364ms/step - loss: 0.5486 - r2_metric: -84.4094 - val_loss: 0.3923 - val_r2_metric: -36.5284
# Epoch 38/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 0.5106 - r2_metric: -79.7623
# Epoch 38: val_loss did not improve from 0.25123
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 16s 359ms/step - loss: 0.5107 - r2_metric: -79.6943 - val_loss: 0.2567 - val_r2_metric: -59.4186
# Epoch 39/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - loss: 0.5219 - r2_metric: -55.5094
# Epoch 39: val_loss did not improve from 0.25123
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 348ms/step - loss: 0.5213 - r2_metric: -55.7638 - val_loss: 0.4046 - val_r2_metric: -37.5683
# Epoch 40/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - loss: 0.4765 - r2_metric: -115.0142
# Epoch 40: val_loss did not improve from 0.25123
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 358ms/step - loss: 0.4764 - r2_metric: -114.6373 - val_loss: 0.3274 - val_r2_metric: -39.4789
# Epoch 41/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - loss: 0.5268 - r2_metric: -73.0985
# Epoch 41: val_loss did not improve from 0.25123
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 357ms/step - loss: 0.5267 - r2_metric: -73.1487 - val_loss: 0.3059 - val_r2_metric: -46.0094
# Epoch 42/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - loss: 0.5120 - r2_metric: -92.4532
# Epoch 42: val_loss did not improve from 0.25123
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 0.5119 - r2_metric: -92.2328 - val_loss: 0.2903 - val_r2_metric: -61.9069
# Epoch 43/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - loss: 0.4304 - r2_metric: -79.0735
# Epoch 43: val_loss did not improve from 0.25123
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s
val_loss did not improve from 0.23917
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 354ms/step - loss: 0.3840 - r2_metric: -66.8557 - val_loss: 0.3366 - val_r2_metric: -45.4298
# Epoch 112/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - loss: 0.4203 - r2_metric: -64.5943
# Epoch 112: val_loss did not improve from 0.23917
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 357ms/step - loss: 0.4204 - r2_metric: -64.4805 - val_loss: 0.3193 - val_r2_metric: -37.3730
# Epoch 113/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - loss: 0.4144 - r2_metric: -66.7939
# Epoch 113: val_loss did not improve from 0.23917
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 362ms/step - loss: 0.4145 - r2_metric: -66.8286 - val_loss: 0.3364 - val_r2_metric: -44.7603
# Epoch 114/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - loss: 0.4637 - r2_metric: -59.0482
# Epoch 114: val_loss did not improve from 0.23917
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 355ms/step - loss: 0.4626 - r2_metric: -59.1151 - val_loss: 0.3337 - val_r2_metric: -54.6188
# Epoch 115/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - loss: 0.4119 - r2_metric: -53.5417
# Epoch 115: val_loss did not improve from 0.23917
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 363ms/step - loss: 0.4121 - r2_metric: -53.5520 - val_loss: 0.3018 - val_r2_metric: -38.0725
# Epoch 116/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 0.4090 - r2_metric: -62.8765
# Epoch 116: val_loss did not improve from 0.23917
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 362ms/step - loss: 0.4091 - r2_metric: -63.2003 - val_loss: 0.3309 - val_r2_metric: -50.9403
# Epoch 117/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - loss: 0.4013 - r2_metric: -63.9084
# Epoch 117: val_loss did not improve from 0.23917
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 16s 367ms/step - loss: 0.4021 - r2_metric: -63.8325 - val_loss: 0.2905 - val_r2_metric: -41.6880
# Epoch 118/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 0.4697 - r2_metric: -56.9607
# Epoch 118: val_loss did not improve from 0.23917
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 16s 362ms/step - loss: 0.4684 - r2_metric: -57.1793 - val_loss: 0.3427 - val_r2_metric: -33.3507
# Epoch 119/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - loss: 0.4139 - r2_metric: -65.3621
# Epoch 119: val_loss did not improve from 0.23917
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 16s 353ms/step - loss: 0.4141 - r2_metric: -65.4891 - val_loss: 0.3481 - val_r2_metric: -48.1492
# Epoch 120/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - loss: 0.4040 - r2_metric: -68.2811
# Epoch 120: val_loss did not improve from 0.23917
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 356ms/step - loss: 0.4039 - r2_metric: -68.2199 - val_loss: 0.2803 - val_r2_metric: -57.2696
# Epoch 121/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - loss: 0.4027 - r2_metric: -57.6160
# Epoch 121: val_loss did not improve from 0.23917
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 356ms/step - loss: 0.4035 - r2_metric: -57.5893 - val_loss: 0.3417 - val_r2_metric: -40.1788
# Epoch 122/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 0.3611 - r2_metric: -58.0975
# Epoch 122: val_loss did not improve from 0.23917
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 360ms/step - loss: 0.3612 - r2_metric: -58.1488 - val_loss: 0.3125 - val_r2_metric: -49.5940
# Epoch 123/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - loss: 0.4278 - r2_metric: -52.6705
# Epoch 123: val_loss did not improve from 0.23917
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 363ms/step - loss: 0.4270 - r2_metric: -52.8335 - val_loss: 0.3459 - val_r2_metric: -41.4677
# Epoch 124/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - loss: 0.4065 - r2_metric: -54.4119
# Epoch 124: val_loss did not improve from 0.23917
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.4057 - r2_metric: -54.5405 - val_loss: 0.2748 - val_r2_metric: -37.1983
# Epoch 125/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - loss: 0.3961 - r2_metric: -70.5346
# Epoch 125: val_loss did not improve from 0.23917
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 355ms/step - loss: 0.3959 - r2_metric: -70.4807 - val_loss: 0.3972 - val_r2_metric: -37.3452
# Epoch 126/500
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - loss: 0.3652 - r2_metric: -66.5610
# Epoch 126: val_loss did not improve from 0.23917
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 357ms/step - loss: 0.3659 - r2_metric: -66.4911 - val_loss: 0.2810 - val_r2_metric: -46.5507
# Epoch 126: early stopping
# Restoring model weights from the end of the best epoch: 26.

# %%
model.save('/content/drive/MyDrive/Contrastive Learning/bags_used_predictor_final.keras')
